# %% [markdown]
# ## Actividad 01 grupo 4
#
# - Crear una lista con números que comiencen por 30 y que termine en 42 haciendo que el paso entre cada número consecutivo sea de 0.4. Sin usar Numpy.

# %%
i = 30 
list= []
while i <= 42:
    list.append(round(i, 2))
    i += 0.4

print(list)
# Out:
# [30, 30.4, 30.8, 31.2, 31.6, 32.0, 32.4, 32.8, 33.2, 33.6, 34.0, 34.4, 34.8, 35.2, 35.6, 36.0, 36.4, 36.8, 37.2, 37.6, 38.0, 38.4, 38.8, 39.2, 39.6, 40.0, 40.4, 40.8, 41.2, 41.6, 42.0]

# %%
lista = []

numero = 30.0  # Empezamos en 30



while numero <= 42.0:  # Terminamos en 42

    lista.append(round(numero, 1))  # Redondeamos a 1 decimal para evitar errores de precisión

    numero += 0.4  # Incrementamos en 0.4



print(lista)
# Out:
# [30.0, 30.4, 30.8, 31.2, 31.6, 32.0, 32.4, 32.8, 33.2, 33.6, 34.0, 34.4, 34.8, 35.2, 35.6, 36.0, 36.4, 36.8, 37.2, 37.6, 38.0, 38.4, 38.8, 39.2, 39.6, 40.0, 40.4, 40.8, 41.2, 41.6, 42.0]

# %% [markdown]
# ## Actividad 02
#
# - Dataset -> https://raw.githubusercontent.com/grammakov/USA-cities-and-states/master/us_cities_states_counties.csv
# - Header -> City|State short|State full|County|City alias
# - Obtener el número de ciudades que tiene el estado de Florida, usando dicho Dataset
# - Sin usar Pandas

# %%
import urllib

url = "https://raw.githubusercontent.com/grammakov/USA-cities-and-states/master/us_cities_states_counties.csv"

# Devuelve un fichero desde una url como cadena de caracteres
def read_url(url):
    return urllib.request.urlopen(url).read().decode('utf-8')

# Descargar un fichero desde una url a una ruta local
def download_file(url, dest):
    urllib.request.urlretrieve(url, dest)
    return

# %%
import csv
import pandas as pd
download_file(url, 'data.csv')
with open('data.csv', newline='') as file:
    cities = csv.reader(file, delimiter='|')
    names = next(cities)  
    cities_florida = set()
    for line in csv.DictReader(file, delimiter='|', fieldnames=names):        
        if line['State full'] == 'Florida':            
            cities_florida.add(line['City'])
    print(len(cities_florida))
# Out:
# 537
# 537

# %%
import urllib.request



def read_url(url):

    return urllib.request.urlopen(url).read().decode('utf-8')



url = "https://raw.githubusercontent.com/grammakov/USA-cities-and-states/master/us_cities_states_counties.csv"

datos = read_url(url)



# Dividir el archivo en líneas y filtrar las de Florida

lineas = datos.split('\n')

ciudades_florida = set()  # Usamos un conjunto para evitar duplicados



for linea in lineas[1:]:  # Saltamos el encabezado

    if '|Florida|' in linea:  # Buscamos el estado completo (evitamos abreviaturas)
        'Holtsville|NY|New York|SUFFOLK|Internal Revenue Service'
        ciudad = linea.split('|')[0].strip()  # Extraemos el primer campo (ciudad)

        if ciudad:  # Aseguramos que no esté vacío

            ciudades_florida.add(ciudad)



print(f"El estado de Florida tiene {len(ciudades_florida)} ciudades únicas.")
# Out:
# El estado de Florida tiene 537 ciudades únicas.
